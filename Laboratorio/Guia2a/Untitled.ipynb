# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
def read_dataset(file_name: str) -> pd.DataFrame:
    """
    Lee un archivo xlsx y lo devuelve como un DataFrame
    """
    return pd.read_excel(file_name)

def info_dataset(df: pd.DataFrame) -> None:
    """
    Info de interés del dataframe
    """

    # Edades, categorías de trabajo, categorías de educación e intervalo de horas trabajadas por semana
    print(f'Edad mínima: {df["age"].min()} - Edad máxima: {df["age"].max()}')
    print(f'Categorías de trabajo: {", ".join(df["workclass"].unique())}')
    print(f'Categorías de educación: {", ".join(df["education"].unique())}')
    print(f'Intervalo de horas trabajadas p/ semana: {df["hours.per.week"].min()} - {df["hours.per.week"].max()}')

# %%
df = read_dataset('dataset_guía_2_adult_census.xlsx')

# Observamos las primeras 20 filas
df.head(20)
# Out:
#     age         workclass     education  education.num marital.status  \
# 0    90                 ?       HS-grad              9        Widowed
# 1    82           Private       HS-grad              9        Widowed
# 2    66                 ?  Some-college             10        Widowed
# 3    54           Private       7th-8th              4       Divorced
# 4    41           Private  Some-college             10      Separated
# 5    34           Private       HS-grad              9       Divorced
# 6    38           Private          10th              6      Separated
# 7    74         State-gov     Doctorate             16  Never-married
# 8    68       Federal-gov       HS-grad              9       Divorced
# 9    41           Private  Some-college             10  Never-married
# 10   45           Private     Doctorate             16       Divorced
# 11   38  Self-emp-not-inc   Prof-school             15  Never-married
# 12   52           Private     Bachelors             13        Widowed
# 13   32           Private       Masters             14      Separated
# 14   51                 ?     Doctorate             16  Never-married
# 15   46           Private   Prof-school             15       Divorced
# 16   45           Private          11th              7       Divorced
# 17   57           Private       Masters             14       Divorced
# 18   22           Private    Assoc-acdm             12  Never-married
# 19   34           Private     Bachelors             13      Separated
#
#            occupation    relationship   race     sex  hours.per.week  \
# 0                   ?   Not-in-family  White  Female              40
# 1     Exec-managerial   Not-in-family  White  Female              18
# 2                   ?       Unmarried  Black  Female              40
# 3   Machine-op-inspct       Unmarried  White  Female              40
# 4      Prof-specialty       Own-child  White  Female              40
# 5       Other-service       Unmarried  White  Female              45
# 6        Adm-clerical       Unmarried  White    Male              40
# 7      Prof-specialty  Other-relative  White  Female              20
# 8      Prof-specialty   Not-in-family  White  Female              40
# 9        Craft-repair       Unmarried  White    Male              60
# 10     Prof-specialty       Unmarried  Black  Female              35
# 11     Prof-specialty   Not-in-family  White    Male              45
# 12      Other-service   Not-in-family  White  Female              20
# 13    Exec-managerial   Not-in-family  White    Male              55
# 14                  ?   Not-in-family  White    Male              40
# 15     Prof-specialty   Not-in-family  White    Male              40
# 16   Transport-moving   Not-in-family  White    Male              76
# 17    Exec-managerial   Not-in-family  White    Male              50
# 18  Handlers-cleaners   Not-in-family  Black    Male              40
# 19              Sales   Not-in-family  White    Male              50
#
#    native.country income
# 0   United-States  <=50K
# 1   United-States  <=50K
# 2   United-States  <=50K
# 3   United-States  <=50K
# 4   United-States  <=50K
# 5   United-States  <=50K
# 6   United-States  <=50K
# 7   United-States   >50K
# 8   United-States  <=50K
# 9               ?   >50K
# 10  United-States   >50K
# 11  United-States   >50K
# 12  United-States   >50K
# 13  United-States   >50K
# 14  United-States   >50K
# 15  United-States   >50K
# 16  United-States   >50K
# 17  United-States   >50K
# 18              ?   >50K
# 19  United-States   >50K

# %%
info_dataset(df=df)
# Out:
# Edad mínima: 17 - Edad máxima: 90
# Categorías de trabajo: ?, Private, State-gov, Federal-gov, Self-emp-not-inc, Self-emp-inc, Local-gov, Without-pay, Never-worked
# Categorías de educación: HS-grad, Some-college, 7th-8th, 10th, Doctorate, Prof-school, Bachelors, Masters, 11th, Assoc-acdm, Assoc-voc, 1st-4th, 5th-6th, 12th, 9th, Preschool
# Intervalo de horas trabajadas p/ semana: 1 - 99

# %%
# Punto 2
# df.plot(x='sex', y='income', kind='bar')
df_g50K = df[df.income == '>50K']['age']
df_lt50K = df[df.income == '<=50K']['age']
df.plot(
    x=[
        df_g50K[df.sex == 'Male'],
        df_g50K[df.sex == 'Female'],
        df_lt50K[df.sex == 'Male'],
        df_lt50K[df.sex == 'Female']
    ],
    y=['M >50K', 'F >50K', 'M <= 50K', 'F <= 50K'],
    kind='bar'
)
# Out:
# C:\Users\Javo\Documents\UNSAM\Intro_Ciencia_Datos\venv\lib\site-packages\pandas\core\common.py:241: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   result = np.asarray(values, dtype=dtype)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [20], in <cell line: 5>()
#       3 df_g50K = df[df.income == '>50K']['age']
#       4 df_lt50K = df[df.income == '<=50K']['age']
# ----> 5 df.plot(
#       6     x=[
#       7         df_g50K[df.sex == 'Male'],
#       8         df_g50K[df.sex == 'Female'],
#       9         df_lt50K[df.sex == 'Male'],
#      10         df_lt50K[df.sex == 'Female']
#      11     ],
#      12     y=['M >50K', 'F >50K', 'M <= 50K', 'F <= 50K'],
#      13     kind='bar'
#      14 )
#
# File ~\Documents\UNSAM\Intro_Ciencia_Datos\venv\lib\site-packages\pandas\plotting\_core.py:937, in PlotAccessor.__call__(self, *args, **kwargs)
#     935 if is_integer(x) and not data.columns.holds_integer():
#     936     x = data_cols[x]
# --> 937 elif not isinstance(data[x], ABCSeries):
#     938     raise ValueError("x must be a label or position")
#     939 data = data.set_index(x)
#
# File ~\Documents\UNSAM\Intro_Ciencia_Datos\venv\lib\site-packages\pandas\core\frame.py:3511, in DataFrame.__getitem__(self, key)
#    3509     if is_iterator(key):
#    3510         key = list(key)
# -> 3511     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3513 # take() does not accept boolean indexers
#    3514 if getattr(indexer, "dtype", None) == bool:
#
# File ~\Documents\UNSAM\Intro_Ciencia_Datos\venv\lib\site-packages\pandas\core\indexes\base.py:5777, in Index._get_indexer_strict(self, key, axis_name)
#    5774     keyarr = com.asarray_tuplesafe(keyarr)
#    5776 if self._index_as_unique:
# -> 5777     indexer = self.get_indexer_for(keyarr)
#    5778     keyarr = self.reindex(keyarr)[0]
#    5779 else:
#
# File ~\Documents\UNSAM\Intro_Ciencia_Datos\venv\lib\site-packages\pandas\core\indexes\base.py:5764, in Index.get_indexer_for(self, target)
#    5746 """
#    5747 Guaranteed return of an indexer even when non-unique.
#    5748
#    (...)
#    5761 array([0, 2])
#    5762 """
#    5763 if self._index_as_unique:
# -> 5764     return self.get_indexer(target)
#    5765 indexer, _ = self.get_indexer_non_unique(target)
#    5766 return indexer
#
# File ~\Documents\UNSAM\Intro_Ciencia_Datos\venv\lib\site-packages\pandas\core\indexes\base.py:3784, in Index.get_indexer(self, target, method, limit, tolerance)
#    3779     target = target.astype(dtype, copy=False)
#    3780     return this._get_indexer(
#    3781         target, method=method, limit=limit, tolerance=tolerance
#    3782     )
# -> 3784 return self._get_indexer(target, method, limit, tolerance)
#
# File ~\Documents\UNSAM\Intro_Ciencia_Datos\venv\lib\site-packages\pandas\core\indexes\base.py:3809, in Index._get_indexer(self, target, method, limit, tolerance)
#    3804         # error: "IndexEngine" has no attribute "_extract_level_codes"
#    3805         tgt_values = engine._extract_level_codes(  # type: ignore[attr-defined]
#    3806             target
#    3807         )
# -> 3809     indexer = self._engine.get_indexer(tgt_values)
#    3811 return ensure_platform_int(indexer)
#
# File ~\Documents\UNSAM\Intro_Ciencia_Datos\venv\lib\site-packages\pandas\_libs\index.pyx:305, in pandas._libs.index.IndexEngine.get_indexer()
#
# File pandas\_libs\hashtable_class_helper.pxi:5247, in pandas._libs.hashtable.PyObjectHashTable.lookup()
#
# TypeError: unhashable type: 'Series'
